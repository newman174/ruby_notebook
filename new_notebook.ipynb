# %% [markdown]
# # New Notebook

# %% [markdown]
# yo yo

# %% [markdown]
# what it done?

# %% [markdown]
# 01

# %% [markdown]
# 02

# %% [markdown]
# 03

# %% [markdown]
# 04

# %% [markdown]
# 05

# %% [markdown]
# 06

# %% [markdown]
# 07

# %% [markdown]
# 08

# %% [markdown]
# 09

# %% [markdown]
# 10

# %% [markdown]
# 11

# %% [markdown]
# 12
