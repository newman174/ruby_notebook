# %% [markdown]
# # New Notebook

# %% [markdown]
# 2022-01-11 16:21:56 -0500

# %% [markdown]
# 2022-01-11 16:21:58 -0500

# %% [markdown]
# 2022-01-11 16:22:55 -0500

# %% [markdown]
# 2022-01-11 16:23:42 -0500

# %% [markdown]
# 2022-01-11 16:23:43 -0500

# %% [markdown]
# 2022-01-11 16:25:57 -0500

# %%
a = 'hello world'
puts a
# Out:
# hello world
